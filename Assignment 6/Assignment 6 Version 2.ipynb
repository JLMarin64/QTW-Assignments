# %% [markdown]
# <center><h1>Unit 12 Case Study</h1> </center>
#
# <center><h2>Cho Kim, Jason Lin, Jonathan Marin</h2> </center>
#
# <br/>
#
# <center><h2>April 4, 2019</h2></center>

# %% [markdown]
# ## Introduction
#
# For this case study, we are using the HIGGS Data Set from the UCI Machine Learning repository to better understand neural networks using TensorFlow.

# %%
import tensorflow as tf

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from sklearn.metrics import roc_auc_score
import pandas as pd
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
N=1000000. #Change this line adjust the number of rows. 
data=pd.read_csv("HIGGS.csv",nrows=N,header=None)
test_data=pd.read_csv("HIGGS.csv",nrows=10000,header=None,skiprows=10500000)

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Work
#
# ## 1.	Pick 3 or more different architectures (add/subtract layers+neurons) and run the model + score.

# %% [markdown]
# ### 1st Model: 3 Layer Architecture 50 neurons/layer
# | Layer (type)              | Output Shape |
# |---------------------------|--------------|
# | dense_1 (Dense)           | (None, 50)   |
# | activation_1 (Activation) | (None, 50)   |
# | dropout_1 (Dropout)       | (None, 50)   |
# | dense_2 (Dense)           | (None, 50)   |
# | activation_2 (Activation) | (None, 50)   |
# | dropout_2 (Dropout)       | (None, 50)   |
# | dense_3 (Dense)           | (None, 1)    |
# | activation_3 (Activation) | (None, 1)    |
#
# ROC Score: `.834`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='uniform'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('sigmoid'))

model.summary()

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=1000)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 50)                1450
# _________________________________________________________________
# activation_1 (Activation)    (None, 50)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                2550
# _________________________________________________________________
# activation_2 (Activation)    (None, 50)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# ...

# %% [markdown]
# ### 2nd Model: 4 Layer Architecture 100 neurons/layer
#
# | Layer (type)               | Output Shape |
# |----------------------------|--------------|
# | dense_4 (Dense)            | (None, 100)  |
# | activation_4 (Activation)  | (None, 100)  |
# | dropout_3 (Dropout)        | (None, 100)  |
# | dense_5 (Dense)            | (None, 100)  |
# | activation_5 (Activation)  | (None, 100)  |
# | dropout_4 (Dropout)        | (None, 100)  |
# | dense_6 (Dense)            | (None, 100)  |
# | activation_6 (Activation)  | (None, 100)  |
# | dropout_5 (Dropout)        | (None, 100)  |
# | dense_7 (Dense)           | (None, 1)    |
# | activation_7 (Activation) | (None, 1)    |
#
# ROC Score `.821`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(100, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.3))
model.add(Dense(100, kernel_initializer='uniform'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.20))
model.add(Dense(100, kernel_initializer='uniform'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('sigmoid'))

model.summary()

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=1000)
roc_auc_score(y_test,model.predict(x_test))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 100)               2900
# _________________________________________________________________
# activation_4 (Activation)    (None, 100)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_5 (Activation)    (None, 100)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# ...

# %% [markdown]
# ### 3rd Model: 3 Layer Architecture 25 neurons/layer
#
# | Layer (type)               | Output Shape |
# |----------------------------|--------------|
# | dense_8 (Dense)            | (None, 25)   |
# | activation_8 (Activation)  | (None, 25)   |
# | dropout_6 (Dropout)        | (None, 25)   |
# | dense_9 (Dense)            | (None, 25)   |
# | activation_9 (Activation)  | (None, 25)   |
# | dropout_7 (Dropout)        | (None, 25)   |
# | dense_10 (Dense)           | (None, 1)    |
# | activation_10 (Activation) | (None, 1)    |
#
# ROC Score: `.819`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(25, kernel_initializer='uniform'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('sigmoid'))

model.summary()

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=1000)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 25)                725
# _________________________________________________________________
# activation_8 (Activation)    (None, 25)                0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 25)                650
# _________________________________________________________________
# activation_9 (Activation)    (None, 25)                0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 26
# ...

# %% [markdown]
# The 1st model performed the best with the highest ROC score of `.834`

# %% [markdown]
# # 2.	With those same 3 architectures, run the SAME architecture but with 2 different (from sigmoid) activation functions.  Google the Keras documentation for a look at different available activations.

# %% [markdown]
# ## Activation: ReLU

# %% [markdown]
# ### 1st Model: ReLU Activation Function
# ROC Score: `.482`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('relu'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='uniform'))
model.add(Activation('relu'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('relu'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=1000)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4990 - acc: 4.6300e-04
# Epoch 2/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 3/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 4/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 5/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 6/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 7/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 8/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 9/1000
# ...

# %% [markdown]
# ### 2nd Model: ReLU Activation Function
#
# ROC score: `.465`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(100, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(100, kernel_initializer='uniform'))
model.add(Activation('relu'))
model.add(Dropout(0.20))
model.add(Dense(100, kernel_initializer='uniform'))
model.add(Activation('relu'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('relu'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=1000)
roc_auc_score(y_test,model.predict(x_test))
# Out:
# Epoch 1/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4974 - acc: 4.8600e-04
# Epoch 2/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 3/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 4/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 5/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 6/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 7/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 8/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 9/1000
# ...

# %% [markdown]
# ### 3rd Model: ReLU Activation Function
#
# ROC Score: `.464`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('relu'))
model.add(Dropout(0.10))
model.add(Dense(25, kernel_initializer='uniform'))
model.add(Activation('relu'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('relu'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=1000)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4977 - acc: 4.5800e-04
# Epoch 2/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 3/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 4/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 5/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 6/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 7/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 8/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.0000e+00
# Epoch 9/1000
# ...

# %% [markdown]
# The best ROC score out of the ReLU activation function models was the 1st model with `.482`
# This is worse than the 1st model with the sigmoid activation function.

# %% [markdown]
# # Activation Tanh

# %% [markdown]
# ### 1st Model: Tanh Activation Function
#
# ROC Score: `.5`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('tanh'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='uniform'))
model.add(Activation('tanh'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('tanh'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=1000)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4974 - acc: 0.5296
# Epoch 2/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.5297
# Epoch 3/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.5297
# Epoch 4/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.5297
# Epoch 5/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.5297
# Epoch 6/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.5297
# Epoch 7/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.5297
# Epoch 8/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.5297
# Epoch 9/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 7.4981 - acc: 0.5297
# Epoch 10/1000
# ...

# %% [markdown]
# ### 2nd Model: Tanh Activation Function
#
# ROC Score: `0.5`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(100, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('tanh'))
model.add(Dropout(0.3))
model.add(Dense(100, kernel_initializer='uniform'))
model.add(Activation('tanh'))
model.add(Dropout(0.20))
model.add(Dense(100, kernel_initializer='uniform'))
model.add(Activation('tanh'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('tanh'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=1000)
roc_auc_score(y_test,model.predict(x_test))
# Out:
# Epoch 1/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4980 - acc: 0.5296
# Epoch 2/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.5297
# Epoch 3/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.5297
# Epoch 4/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.5297
# Epoch 5/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.5297
# Epoch 6/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.5297
# Epoch 7/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.5297
# Epoch 8/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.5297
# Epoch 9/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 7.4981 - acc: 0.5297
# Epoch 10/1000
# ...

# %% [markdown]
# ### 3rd Model: Tanh Activation Function
#
# ROC Score: `0.5`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('tanh'))
model.add(Dropout(0.10))
model.add(Dense(25, kernel_initializer='uniform'))
model.add(Activation('tanh'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('tanh'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=1000)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 8.5215 - acc: 0.0032
# Epoch 2/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 8.5373 - acc: 0.0000e+00
# Epoch 3/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 8.5373 - acc: 0.0000e+00
# Epoch 4/1000
# 1000000/1000000 [==============================] - 4s 4us/step - loss: 8.5373 - acc: 1.0000e-06
# Epoch 5/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 8.5373 - acc: 1.0000e-06
# Epoch 6/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 8.5373 - acc: 0.0000e+00
# Epoch 7/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 8.5373 - acc: 0.0000e+00
# Epoch 8/1000
# 1000000/1000000 [==============================] - 3s 3us/step - loss: 8.5373 - acc: 0.0000e+00
# Epoch 9/1000
# ...

# %% [markdown]
# All of the tanh activation functions performed the same with a ROC score of `0.5`.

# %% [markdown]
# # 3.	Take your best model from parts 1&2 and vary the batch size by at least 2 orders of magnitude

# %% [markdown]
# We used the sigmoid activation function with 3 layers and 100 neurons. The first model had a batch size of 1000.

# %% [markdown]
# ### Increasing from Batch Size 1000 to 10000
#
# We tried 100,000 but ran out of memory due to a ResourceExhaustedError so we used 10,000.
#
# Increasing our batch size gave us a ROC score of `.657` which is lower than our best model from parts 1 and 2.

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='uniform'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=50, batch_size=10000)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/50
# 1000000/1000000 [==============================] - 1s 1us/step - loss: 0.6916 - acc: 0.5295
# Epoch 2/50
# 1000000/1000000 [==============================] - 1s 1us/step - loss: 0.6915 - acc: 0.5297
# Epoch 3/50
# 1000000/1000000 [==============================] - 1s 1us/step - loss: 0.6914 - acc: 0.5297
# Epoch 4/50
# 1000000/1000000 [==============================] - 1s 1us/step - loss: 0.6914 - acc: 0.5297
# Epoch 5/50
# 1000000/1000000 [==============================] - 1s 1us/step - loss: 0.6914 - acc: 0.5297
# Epoch 6/50
# 1000000/1000000 [==============================] - 1s 1us/step - loss: 0.6914 - acc: 0.5297
# Epoch 7/50
# 1000000/1000000 [==============================] - 1s 1us/step - loss: 0.6914 - acc: 0.5297
# Epoch 8/50
# 1000000/1000000 [==============================] - 1s 1us/step - loss: 0.6914 - acc: 0.5297
# Epoch 9/50
# 1000000/1000000 [==============================] - 1s 1us/step - loss: 0.6914 - acc: 0.5297
# Epoch 10/50
# ...

# %% [markdown]
# ### Decreasing batch size from 1000 to 100
#
# Decreasing the batch size from 1000 to 100 resulted in slower model run times. Each epoch took 27 times longer to run. Therefore, we only ran 20 epochs due to time constraints.
#
# This produced a ROC score of `.802`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='uniform'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=20, batch_size=100)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/20
# 1000000/1000000 [==============================] - 28s 28us/step - loss: 0.6537 - acc: 0.6051
# Epoch 2/20
# 1000000/1000000 [==============================] - 27s 27us/step - loss: 0.6170 - acc: 0.6598
# Epoch 3/20
# 1000000/1000000 [==============================] - 27s 27us/step - loss: 0.6024 - acc: 0.6752
# Epoch 4/20
# 1000000/1000000 [==============================] - 27s 27us/step - loss: 0.5958 - acc: 0.6808
# Epoch 5/20
# 1000000/1000000 [==============================] - 27s 27us/step - loss: 0.5900 - acc: 0.6858
# Epoch 6/20
# 1000000/1000000 [==============================] - 27s 27us/step - loss: 0.5850 - acc: 0.6904
# Epoch 7/20
# 1000000/1000000 [==============================] - 27s 27us/step - loss: 0.5809 - acc: 0.6938
# Epoch 8/20
# 1000000/1000000 [==============================] - 28s 28us/step - loss: 0.5771 - acc: 0.6972
# Epoch 9/20
# 1000000/1000000 [==============================] - 27s 27us/step - loss: 0.5739 - acc: 0.6997
# Epoch 10/20
# ...

# %% [markdown]
# ### Decreasing batch size from 1000 to 500
#
# We ran 1000 epochs after decreasing our batch size to 500. This gave us a ROC score of `.838`.

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='uniform'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=500)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/1000
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6921 - acc: 0.5258
# Epoch 2/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6726 - acc: 0.5735
# Epoch 3/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6463 - acc: 0.6190
# Epoch 4/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6324 - acc: 0.6378
# Epoch 5/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6236 - acc: 0.6484
# Epoch 6/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6165 - acc: 0.6568
# Epoch 7/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6105 - acc: 0.6646
# Epoch 8/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6051 - acc: 0.6706
# Epoch 9/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6014 - acc: 0.6739
# Epoch 10/1000
# ...

# %% [markdown]
# # 4.	Take your best model (score) from parts 1&2 and use 3 different kernel initializers. Use a reasonable batch size.

# %% [markdown]
# ### RandomNormal Kernel Initializer

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='RandomNormal')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='RandomNormal'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='RandomNormal')) 
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=1000, batch_size=500)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/1000
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6855 - acc: 0.5439
# Epoch 2/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6510 - acc: 0.6120
# Epoch 3/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6382 - acc: 0.6279
# Epoch 4/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6286 - acc: 0.6403
# Epoch 5/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6215 - acc: 0.6500
# Epoch 6/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6150 - acc: 0.6583
# Epoch 7/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6095 - acc: 0.6655
# Epoch 8/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6046 - acc: 0.6699
# Epoch 9/1000
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6004 - acc: 0.6746
# Epoch 10/1000
# ...

# %% [markdown]
# The ROC score for the `RandomNormal` kernel initializer is `.836`.

# %% [markdown]
# ### he_uniform Kernel Initializer

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin
model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='he_uniform')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='he_uniform'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='he_uniform'))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

# reduced epochs to 30 to run quickly
model.fit(x, y, epochs=100, batch_size=500)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6641 - acc: 0.5887
# Epoch 2/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6368 - acc: 0.6300
# Epoch 3/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6246 - acc: 0.6452
# Epoch 4/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6148 - acc: 0.6576
# Epoch 5/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6070 - acc: 0.6663
# Epoch 6/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6017 - acc: 0.6717
# Epoch 7/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.5977 - acc: 0.6762
# Epoch 8/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.5937 - acc: 0.6797
# Epoch 9/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.5906 - acc: 0.6818
# Epoch 10/100
# ...

# %% [markdown]
# The ROC score for the `he_uniform` kernel initializer is `.820 `.

# %% [markdown]
# ### VarianceScaling Kernel Initializer

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='VarianceScaling')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='VarianceScaling'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='VarianceScaling')) 
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=sgd)

model.fit(x, y, epochs=100, batch_size=500)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6661 - acc: 0.5856
# Epoch 2/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6417 - acc: 0.6259
# Epoch 3/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6299 - acc: 0.6399
# Epoch 4/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6214 - acc: 0.6497
# Epoch 5/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6130 - acc: 0.6598
# Epoch 6/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6067 - acc: 0.6675
# Epoch 7/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6011 - acc: 0.6734
# Epoch 8/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.5973 - acc: 0.6768
# Epoch 9/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.5941 - acc: 0.6802
# Epoch 10/100
# ...

# %% [markdown]
# The ROC score for the `VarianceScaling` kernel initializer is `.821`.

# %% [markdown]
# # 5.	Take your best results from #3 and try 3 different optimizers.

# %% [markdown]
# Our best result was using the `RandomNormal` kernel initializer.

# %% [markdown]
# ### Adadelta Optimizer
#
# The ROC score is `.808`.

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='RandomNormal')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='RandomNormal'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='RandomNormal')) 
model.add(Activation('sigmoid'))

#sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='Adadelta')

model.fit(x, y, epochs=100, batch_size=500)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/100
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.6848 - acc: 0.5487
# Epoch 2/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6538 - acc: 0.6095
# Epoch 3/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6465 - acc: 0.6199
# Epoch 4/100
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.6418 - acc: 0.6259
# Epoch 5/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6351 - acc: 0.6333
# Epoch 6/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6282 - acc: 0.6405
# Epoch 7/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6222 - acc: 0.6483
# Epoch 8/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6173 - acc: 0.6548
# Epoch 9/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6126 - acc: 0.6616
# Epoch 10/100
# ...

# %% [markdown]
# ### Nadam Optimizer
#
# The ROC score is `.828`

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='RandomNormal')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='RandomNormal'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='RandomNormal')) 
model.add(Activation('sigmoid'))

#sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='Nadam')

model.fit(x, y, epochs=100, batch_size=500)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/100
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.6506 - acc: 0.6131
# Epoch 2/100
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.6285 - acc: 0.6408
# Epoch 3/100
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.6110 - acc: 0.6619
# Epoch 4/100
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5999 - acc: 0.6742
# Epoch 5/100
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5933 - acc: 0.6805
# Epoch 6/100
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5889 - acc: 0.6844
# Epoch 7/100
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5849 - acc: 0.6871
# Epoch 8/100
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5818 - acc: 0.6900
# Epoch 9/100
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5788 - acc: 0.6925
# Epoch 10/100
# ...

# %% [markdown]
# ### RMSprop Optimizer
#
# The ROC score is `.731`.

# %%
from keras.optimizers import RMSprop

y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='uniform')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='uniform'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='uniform')) 
model.add(Activation('sigmoid'))

#sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
rmsprop = RMSprop(lr=0.1)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=rmsprop)

model.fit(x, y, epochs=100, batch_size=500)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6736 - acc: 0.5893
# Epoch 2/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6447 - acc: 0.6310
# Epoch 3/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6342 - acc: 0.6447
# Epoch 4/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6264 - acc: 0.6535
# Epoch 5/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6234 - acc: 0.6569
# Epoch 6/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6225 - acc: 0.6570
# Epoch 7/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6209 - acc: 0.6587
# Epoch 8/100
# 1000000/1000000 [==============================] - 6s 6us/step - loss: 0.6193 - acc: 0.6602
# Epoch 9/100
# 1000000/1000000 [==============================] - 7s 7us/step - loss: 0.6184 - acc: 0.6611
# Epoch 10/100
# ...

# %% [markdown]
# # 6.	Take all that you’ve learned so far and give your best shot at producing a score.
#
# RandomNormal kernel_initializer
#
# 3 layer Neural Network with 50 neurons/layer, 1 neuron/layer for the output layer
#
# Sigmoid activation function
#
# Nadam optimizer
#
# These parameters gave us the best accuracy score out of the runs.
#
# In a previous notebook version where the Nadam Optimizer ran for 1000 epochs, it performed the best out of the 4 different optimizer options. Therefore, for our final model we chose to go with the Nadam optimizer instead of SGD.

# %%
y = np.array(data.loc[:,0])
x = np.array(data.loc[:,1:])
x_test = np.array(test_data.loc[:,1:])
y_test = np.array(test_data.loc[:,0])

#Begin 

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='RandomNormal')) # X_train.shape[1] == 28 here
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(50, kernel_initializer='RandomNormal'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.10))
model.add(Dense(1, kernel_initializer='RandomNormal')) 
model.add(Activation('sigmoid'))

#sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='Nadam')

model.fit(x, y, epochs=500, batch_size=500)
roc_auc_score(y_test,model.predict(x_test))
#end
# Out:
# Epoch 1/500
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.6506 - acc: 0.6130
# Epoch 2/500
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.6265 - acc: 0.6444
# Epoch 3/500
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.6092 - acc: 0.6643
# Epoch 4/500
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5997 - acc: 0.6750
# Epoch 5/500
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5935 - acc: 0.6797
# Epoch 6/500
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5890 - acc: 0.6827A:
# Epoch 7/500
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5848 - acc: 0.6869
# Epoch 8/500
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5816 - acc: 0.6889
# Epoch 9/500
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.5789 - acc: 0.6921
# Epoch 10/500
# ...

# %% [markdown]
# # Q1: What was the effect of adding more layers/neurons.

# %% [markdown]
# When adding layers/neurons the accuracy does not have a wide fluctuation for the three architectures that have been estimated. The base model for comparsion is 3 layers with 50 neurons in each layer `(accuracy = 0.834)`. When the number of layers increased to 4 and the number of neurons increased to 100 for each layer, the accuracy `(0.821)` is lower than the base model. When decreasing the number of neurons to 25, the accuracy `(0.819)` is lower than the base model but slightly lower than the 4 layer model with 100 neurons in each layer.
#
# For us, adding an additional layer and increasing neurons decreased the accuracy. Also, keeping the number of layers the same and decreasing neurons by half also decreased the accuracy.

# %% [markdown]
# # Q2: Which parameters gave you the best result and why (in your opinion) did they work.

# %% [markdown]
# The parameters that worked is using `RandomNormal` kernel initializer, `Sigmoid` activation function, and `Nadam` optimization. The `RandomNormal` kernel initializer generates tensors with a normal distribution. The main difference between He_Uniform and the Uniform kernel initializer is that the range to which the intial random weight matrix is created is wider for He_Uniform than the Uniform. Therefore, it seems the "true" weight matrix is outside the range of Uniform. Also using Sigmoid activation seems to be the best, especially, for classifiers. Because of the S shape, bounded between 0 to 1 it seems ideal for this dataset. Tanh is also used since it follows this same shape, however, the accuracy is horrible indicating that it may fall out of the range for the function. The Nadam optimizer seems to be the best since it utilizes the Nesterov momentum, which is like a "corrector" for the gradient descent. The optimizer also uses preivous gradients, which are utilized in the calculation of the current gradient descent. Therefore, able to converge to the minimum faster for the loss function. Also from the previous runs adding layers and decreasing neurons show a drop in accuracy. This seems to indicate that layers does not increase accuracy, but maybe the current or higher neuron count may increase the accuracy since there is more neurons to learn the data. Also having a smaller batch size seems to increase accuracy but increased run time. The smaller batch size is able to have the model "learn" more from the data, and therefore not have the model miss any important information. From the testing, increasing batch decreased accuracy but decreasing batch size increased accuracy.
#
# https://medium.com/the-theory-of-everything/understanding-activation-functions-in-neural-networks-9491262884e0
# https://archive.ics.uci.edu/ml/datasets/HIGGS
# https://towardsdatascience.com/stochastic-gradient-descent-with-momentum-a84097641a5d
# https://medium.com/konvergen/momentum-method-and-nesterov-accelerated-gradient-487ba776c987
#
# https://towardsdatascience.com/epoch-vs-iterations-vs-batch-size-4dfb9c7ce9c9
#
# https://keras.io/optimizers/

# %% [markdown]
# # Q3: For #6, how did you decide that your model was ‘done’

# %% [markdown]
# The model is "done" because of using the information provided by the architecture, activation, batch size, kernel intializer, and optimizer, it gives us a loss score and an accuracy score. Once the epochs reached a certain point where each subsequent accuracy score reached the maximum value and the loss was minimized was when the model was done training.
#
# From each of the studies, the parameters that creates the "highest" accuracy is used in the final model, and therefore when these parameters used has the highest accuracy of 0.8391 compared to the original base model accuracy of 0.8265. At this point, there seems to show diminishing returns in increasing accuracy since using these parameters may increase run time for an increase accuracy of 2%. Therefore, if there are no drastic changes in accuracy when "turning the knobs" then it should be "done"
